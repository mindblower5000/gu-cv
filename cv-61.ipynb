# %% [markdown]
# ### HW6 Мельчук А.Б.
#
# Обучить сиамскую сеть для верификации лиц на датасете LFW
# Библиотеки: [Python, Tensorflow]

# %%
# %tensorflow_version 2.x
# Out:
# UsageError: Line magic function `%tensorflow_version` not found.

# %%
# !pip install tensorflow_datasets
# Out:
# Requirement already satisfied: tensorflow_datasets in /Users/root1/anaconda3/lib/python3.7/site-packages (3.1.0)
# Requirement already satisfied: tensorflow-metadata in /Users/root1/anaconda3/lib/python3.7/site-packages (from tensorflow_datasets) (0.22.2)
# Requirement already satisfied: promise in /Users/root1/anaconda3/lib/python3.7/site-packages (from tensorflow_datasets) (2.3)
# Requirement already satisfied: tqdm in /Users/root1/anaconda3/lib/python3.7/site-packages (from tensorflow_datasets) (4.36.1)
# Requirement already satisfied: requests>=2.19.0 in /Users/root1/anaconda3/lib/python3.7/site-packages (from tensorflow_datasets) (2.21.0)
# Requirement already satisfied: dill in /Users/root1/anaconda3/lib/python3.7/site-packages (from tensorflow_datasets) (0.3.2)
# Requirement already satisfied: six in /Users/root1/anaconda3/lib/python3.7/site-packages (from tensorflow_datasets) (1.12.0)
# Requirement already satisfied: protobuf>=3.6.1 in /Users/root1/anaconda3/lib/python3.7/site-packages (from tensorflow_datasets) (3.11.3)
# Requirement already satisfied: wrapt in /Users/root1/anaconda3/lib/python3.7/site-packages (from tensorflow_datasets) (1.11.2)
# Requirement already satisfied: future in /Users/root1/anaconda3/lib/python3.7/site-packages (from tensorflow_datasets) (0.17.1)
# Requirement already satisfied: termcolor in /Users/root1/anaconda3/lib/python3.7/site-packages (from tensorflow_datasets) (1.1.0)
# Requirement already satisfied: numpy in /Users/root1/anaconda3/lib/python3.7/site-packages (from tensorflow_datasets) (1.17.2)
# Requirement already satisfied: attrs>=18.1.0 in /Users/root1/anaconda3/lib/python3.7/site-packages (from tensorflow_datasets) (19.2.0)
# Requirement already satisfied: absl-py in /Users/root1/anaconda3/lib/python3.7/site-packages (from tensorflow_datasets) (0.9.0)
# Requirement already satisfied: googleapis-common-protos in /Users/root1/anaconda3/lib/python3.7/site-packages (from tensorflow-metadata->tensorflow_datasets) (1.52.0)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /Users/root1/anaconda3/lib/python3.7/site-packages (from requests>=2.19.0->tensorflow_datasets) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /Users/root1/anaconda3/lib/python3.7/site-packages (from requests>=2.19.0->tensorflow_datasets) (1.24.2)
# Requirement already satisfied: idna<2.9,>=2.5 in /Users/root1/anaconda3/lib/python3.7/site-packages (from requests>=2.19.0->tensorflow_datasets) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/root1/anaconda3/lib/python3.7/site-packages (from requests>=2.19.0->tensorflow_datasets) (2019.9.11)
# Requirement already satisfied: setuptools in /Users/root1/anaconda3/lib/python3.7/site-packages (from protobuf>=3.6.1->tensorflow_datasets) (41.4.0)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from sklearn.manifold import TSNE

import tensorflow as tf
import tensorflow_datasets as tfds

# %% [markdown]
# ### Загрузка датасета LFW

# %%
train_ds, ds_info = tfds.load(
    'lfw',
    as_supervised=True,
    with_info=True,
    split='train',
)
# Out:
# Downloading and preparing dataset lfw/0.1.0 (download: 172.20 MiB, generated: Unknown size, total: 172.20 MiB) to /Users/root1/tensorflow_datasets/lfw/0.1.0...
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Completed...', max=1.0, style=Progre…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Dl Size...', max=1.0, style=ProgressSty…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Extraction completed...', max=1.0, styl…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Shuffling and writing examples to /Users/root1/tensorflow_datasets/lfw/0.1.0.incompleteFM76OI/lfw-train.tfrecord
# HBox(children=(FloatProgress(value=0.0, max=13233.0), HTML(value='')))
# HBox(children=(FloatProgress(value=0.0, description='Computing statistics...', max=1.0, style=ProgressStyle(de…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Dataset lfw downloaded and prepared to /Users/root1/tensorflow_datasets/lfw/0.1.0. Subsequent calls will reuse this data.

# %%
ds_info
# Out:
# tfds.core.DatasetInfo(
#     name='lfw',
#     version=0.1.0,
#     description='Labeled Faces in the Wild:
#         A Database for Studying Face Recognition in
#         Unconstrained Environments',
#     homepage='http://vis-www.cs.umass.edu/lfw',
#     features=FeaturesDict({
#         'image': Image(shape=(250, 250, 3), dtype=tf.uint8),
#         'label': Text(shape=(), dtype=tf.string),
#     }),
#     total_num_examples=13233,
#     splits={
#         'train': 13233,
#     },
#     supervised_keys=('label', 'image'),
#     citation="""@TechReport{LFWTech,
#         author = {Gary B. Huang and Manu Ramesh and Tamara Berg and Erik Learned-Miller},
#         title = {Labeled Faces in the Wild: A Database for Studying Face Recognition in Unconstrained Environments},
#         institution = {University of Massachusetts, Amherst},
#         year = 2007,
#         number = {07-49},
#         month = {October}
#     }""",
#     redistribution_info=,
# )

# %%
for example in train_ds.take(2):
    image, label = example[1], example[0]

    plt.imshow(image.numpy().astype(np.float32)/255)
    print(f"Label: {label}")
# Out:
# Label: b'Tom_Amstutz'
# Label: b'Kimi_Raikkonen'

# %% [markdown]
# ### Создание модели CNN

# %%
EMB_SIZE = 250

model = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(32, (5, 5), padding='same', activation='relu'),
    tf.keras.layers.MaxPool2D((2, 2), (2, 2)),
    tf.keras.layers.Conv2D(64, (5, 5), padding='same', activation='relu'),
    tf.keras.layers.MaxPool2D((2, 2), (2, 2)),
    tf.keras.layers.Conv2D(128, (5, 5), padding='same', activation='relu'),
    tf.keras.layers.MaxPool2D((2, 2), (2, 2)),
    tf.keras.layers.Conv2D(256, (3, 3), padding='same', activation='relu'),
    tf.keras.layers.MaxPool2D((2, 2), (2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(EMB_SIZE, activation=None),
])

# %% [markdown]
# ### Contrastive Loss

# %%
MARGIN = 50.0

def contastive_loss(embs, labels):
    bs = embs.shape[0]
    embs1 = embs[:bs//2, :]
    embs2 = embs[bs//2:, :]
    labels1 = labels[:bs//2]
    labels2 = labels[bs//2:]

    d2 = tf.reduce_sum(tf.square(embs1 - embs2), axis=1)
    d =  tf.sqrt(d2)
    z = tf.cast(labels1 == labels2, tf.float32)
    
    return tf.reduce_mean(z * d2 + (1-z) * tf.maximum(0, MARGIN - d)**2)

# %% [markdown]
# ### Подготовка пайплайна данных

# %%
def normalize_example(label, image):
    return label, tf.cast(image, tf.float32) / 255.

# %%
BATCH_SIZE = 128
NUM_EPOCHS = 10

train_ds = train_ds.map(normalize_example)
train_ds = train_ds.shuffle(buffer_size=10000, seed=5)
train_ds = train_ds.repeat(NUM_EPOCHS)
train_ds = train_ds.batch(BATCH_SIZE)

# %%
train_ds
# Out:
# <BatchDataset shapes: ((None,), (None, 250, 250, 3)), types: (tf.string, tf.float32)>

# %% [markdown]
# ### Визуализация датасета

# %%
some_sample = next(iter(train_ds))
images = some_sample[1].numpy()[:4]
labels = some_sample[0].numpy()[:4]

# %%
labels
# Out:
# array([b'Mahmoud_Abbas', b'Harrison_Ford', b'Ruth_Stubbs',
#        b'Stefano_Basalini'], dtype=object)

# %%
fontdict = {'fontsize': '14', 'color': 'white'}
plt.figure(figsize=(20,10))
for i in range(4):
    plt.subplot(1,4,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(images[i].reshape(250,250,3))
    plt.xlabel(labels[i].decode(), fontdict=fontdict)
plt.show()

# %% [markdown]
# ### Подготовка к обучению

# %%
LEARNING_RATE = 0.001
optimizer = tf.keras.optimizers.Adam(LEARNING_RATE)

# %% [markdown]
# ### Обучение модели

# %%
# %%time

for iteration, (labels, images) in enumerate(train_ds):
    
    # Forward
    with tf.GradientTape() as tape:
        embs = model(images)
        loss_value = contastive_loss(embs, labels)
        
    # Backward
    grads = tape.gradient(loss_value, model.variables)
    optimizer.apply_gradients(zip(grads, model.variables))

    if iteration % 200 == 0:
        print('[{}] Loss: {}'.format(iteration, loss_value.numpy()))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# /usr/local/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/data/ops/iterator_ops.py in __next__(self)
#     628
#     629   def __next__(self):  # For Python 3 compatibility
# --> 630     return self.next()
#     631
#     632   def _next_internal(self):
#
# /usr/local/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/data/ops/iterator_ops.py in next(self)
#     672     """Returns a nested structure of `Tensor`s containing the next element."""
#     673     try:
# --> 674       return self._next_internal()
#     675     except errors.OutOfRangeError:
#     676       raise StopIteration
#
# /usr/local/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/data/ops/iterator_ops.py in _next_internal(self)
#     657             self._iterator_resource,
#     658             output_types=self._flat_output_types,
# --> 659             output_shapes=self._flat_output_shapes)
#     660
#     661       try:
#
# /usr/local/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/gen_dataset_ops.py in iterator_get_next_sync(iterator, output_types, output_shapes, name)
#    2467         _ctx._context_handle, tld.device_name, "IteratorGetNextSync", name,
#    2468         tld.op_callbacks, iterator, "output_types", output_types,
# -> 2469         "output_shapes", output_shapes)
#    2470       return _result
#    2471     except _core._FallbackException:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Тестирование на новых данных

# %%
def load_and_prepare_image(fpath):
    import imageio
    from skimage.transform import resize
    img = imageio.imread(fpath, pilmode="RGB")
    img = img.astype(np.float32)/255
    img = resize(img, (250, 250, 3), mode='reflect', anti_aliasing=True)
    img = np.reshape(img, (250, 250, 3))
    return img

img_a1 = load_and_prepare_image('Arnold_1.jpeg')
img_a2 = load_and_prepare_image('Arnold_2.jpg')
img_b = load_and_prepare_image('Stalone.jpg')
img_c = load_and_prepare_image('Chan.jpg')

# %% [markdown]
# ### Получение эмбеддингов для новых данных

# %%
new_embs = model(np.stack((img_a1, img_a2, img_b, img_c), axis=0))

# %%
img_a1 = load_and_prepare_image('Arnold_1.jpeg')
img_a2 = load_and_prepare_image('Arnold_2.jpg')
img_b = load_and_prepare_image('Stallone.jpg')
img_c = load_and_prepare_image('Chan.jpg')

# %%
def diff(e1, e2):
    return np.sum((e1 - e2)**2) ** 0.5

emb1 = new_embs[0,:] #Arnold_1
emb2 = new_embs[1,:] #Arnold_1
emb3 = new_embs[2,:] #Stallone
emb4 = new_embs[3,:] #Chan

print('Arnold_1 <-> Arnold_1: ', diff(emb1, emb2))
print('Arnold_1<-> Stallone: ', diff(emb1, emb3))
print('Arnold_2 <-> Stallone: ', diff(emb2, emb3))
print('Arnold_1<-> Chan: ', diff(emb1, emb4))
print('Arnold_2<-> Chan: ', diff(emb2, emb4))

# %% [markdown]
# Эмбеддинги фотографий Арнольда Шварценеггера оказались ближе, чем эмбеддинги фотографий других людей.
